# %%
import pandas as pd

df=pandas.read_csv('../../data/raw/games.csv')
df2=df[["victory_status","winner","white_id","white_rating","black_id","black_rating","opening_name"]]

df2
# Out:
#       victory_status winner       white_id  white_rating            black_id  \
# 0          outoftime  white       bourgris          1500                a-00
# 1             resign  black           a-00          1322           skinnerua
# 2               mate  white         ischia          1496                a-00
# 3               mate  white  daniamurashov          1439        adivanov2009
# 4               mate  white      nik221107          1523        adivanov2009
# ...              ...    ...            ...           ...                 ...
# 20053         resign  white        belcolt          1691            jamboger
# 20054           mate  black       jamboger          1233  farrukhasomiddinov
# 20055           mate  white       jamboger          1219        schaaksmurf3
# 20056         resign  white   marcodisogno          1360            jamboger
# 20057           mate  black       jamboger          1235               ffbob
#
# ...
