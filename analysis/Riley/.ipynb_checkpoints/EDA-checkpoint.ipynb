# %%
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt
from scripts import project_functions

df=project_functions.load_and_process('../../data/raw/games.csv')
df
# Out:
#        rated  turns victory_status winner             white_id  white_rating  \
# 9787   False     35         resign  white  -l-_jedi_knight_-l-          1564
# 9035   False    122         resign  black           1111112222          1675
# 6508   False    149           draw   draw               a55s72          1500
# 703    False     60         resign  black               a7twen          1500
# 6524   False      5         resign  white             a_arda_y          1500
# ...      ...    ...            ...    ...                  ...           ...
# 10400   True     43         resign  white                zynko          1494
# 10396   True     87           mate  white                zynko          1501
# 17214   True     26         resign  white            zztopillo          1466
# 14971   True     63         resign  white               zzzbbb          1616
# 19204   True     70         resign  black              zzzimon          1375
#
#              black_id  black_rating  \
# 9787       erik123678          1503
# 9035       crusova_35          1895
# 6508           ak6664          1500
# 703    bloonfreakster          1478
# 6524      mehmetali_t          1518
# ...               ...           ...
# 10400       chebyshev          1843
# 10396         dachnik          1221
# 17214        fazouane          1453
# 14971          wojand          1554
# 19204        jersey86          1500
#
#                                             opening_name first_move_white  \
# 9787       Scandinavian Defense: Mieses-Kotroc Variation               e4
# 9035                    Sicilian Defense: Bowdler Attack               e4
# 6508                              Rat Defense: Harmonist               e4
# 703                                        Kadas Opening               h4
# 6524                                           Ruy Lopez               e4
# ...                                                  ...              ...
# 10400                                  Caro-Kann Defense               e4
# 10396                                  Caro-Kann Defense               e4
# 17214           King's Pawn Game: King's Head Opening #2               e4
# 14971  Italian Game: Giuoco Pianissimo |  Italian Fou...               e4
# 19204                        Ruy Lopez: Steinitz Defense               e4
#
#       first_move_black
# 9787                d5
# 9035                c5
# 6508                d6
# 703                 e5
# 6524                e5
# ...                ...
# 10400               c6
# 10396               c6
# 17214               e5
# 14971               e5
# 19204               e5
#
# [20058 rows x 11 columns]

# %% [markdown]
# # Overal Rating Stats
# ---

# %%
stats=df['white_rating'].describe();
stats
# Out:
# count    20058.000000
# mean      1596.631868
# std        291.253376
# min        784.000000
# 25%       1398.000000
# 50%       1567.000000
# 75%       1793.000000
# max       2700.000000
# Name: white_rating, dtype: float64

# %%
stats=df['black_rating'].describe();
stats
# Out:
# count    20058.000000
# mean      1588.831987
# std        291.036126
# min        789.000000
# 25%       1391.000000
# 50%       1562.000000
# 75%       1784.000000
# max       2723.000000
# Name: black_rating, dtype: float64

# %% [markdown]
# # Turn stats
# ---

# %%
stats=df['turns'].describe();
stats
# Out:
# count    20058.000000
# mean        60.465999
# std         33.570585
# min          1.000000
# 25%         37.000000
# 50%         55.000000
# 75%         79.000000
# max        349.000000
# Name: turns, dtype: float64

# %% [markdown]
# # Cleaning
# ---
# The data set is already cleaned and the only null values in the data set can be found in the *'first_move_black'* column when black resigns on white's first move.

# %% [markdown]
# # Maping
# ---

# %%
for ind, row in df.iterrows():
    df.loc[ind, "diffrence_of_rating"]=abs(row['white_rating']-row['black_rating'])
corr=df.corr()
sns.heatmap(corr, xticklabels=corr.columns, yticklabels=corr.columns, annot=True, cmap=sns.diverging_palette(220, 20, as_cmap=True))
# Out:
# <AxesSubplot:>

# %%
df
# Out:
#        rated  turns victory_status winner             white_id  white_rating  \
# 9787   False     35         resign  white  -l-_jedi_knight_-l-          1564
# 9035   False    122         resign  black           1111112222          1675
# 6508   False    149           draw   draw               a55s72          1500
# 703    False     60         resign  black               a7twen          1500
# 6524   False      5         resign  white             a_arda_y          1500
# ...      ...    ...            ...    ...                  ...           ...
# 10400   True     43         resign  white                zynko          1494
# 10396   True     87           mate  white                zynko          1501
# 17214   True     26         resign  white            zztopillo          1466
# 14971   True     63         resign  white               zzzbbb          1616
# 19204   True     70         resign  black              zzzimon          1375
#
#              black_id  black_rating  \
# 9787       erik123678          1503
# 9035       crusova_35          1895
# 6508           ak6664          1500
# 703    bloonfreakster          1478
# 6524      mehmetali_t          1518
# ...               ...           ...
# 10400       chebyshev          1843
# 10396         dachnik          1221
# 17214        fazouane          1453
# 14971          wojand          1554
# 19204        jersey86          1500
#
#                                             opening_name first_move_white  \
# 9787       Scandinavian Defense: Mieses-Kotroc Variation               e4
# 9035                    Sicilian Defense: Bowdler Attack               e4
# 6508                              Rat Defense: Harmonist               e4
# 703                                        Kadas Opening               h4
# 6524                                           Ruy Lopez               e4
# ...                                                  ...              ...
# 10400                                  Caro-Kann Defense               e4
# 10396                                  Caro-Kann Defense               e4
# 17214           King's Pawn Game: King's Head Opening #2               e4
# 14971  Italian Game: Giuoco Pianissimo |  Italian Fou...               e4
# 19204                        Ruy Lopez: Steinitz Defense               e4
#
#       first_move_black  diffrence_of_rating
# 9787                d5                 61.0
# 9035                c5                220.0
# 6508                d6                  0.0
# 703                 e5                 22.0
# 6524                e5                 18.0
# ...                ...                  ...
# 10400               c6                349.0
# 10396               c6                280.0
# 17214               e5                 13.0
# 14971               e5                 62.0
# 19204               e5                125.0
#
# [20058 rows x 12 columns]

# %% [markdown]
# The positive correlation between black and whites rating means players are matched up with players of simular rating. There is a slight correlation between the diffrence_of_rating and the amount of turns in the game. This also makes sense because the the better one player is than the other, the more easily they can win. This diffrence may be more apparent if player were not matched against players of simular strength.

# %%
dict={}
for ind, row in df.iterrows():
    if(row['opening_name'] not in dict):
        dict[row['opening_name']]=0
    if(row['winner']=='white'):
        dict[row['opening_name']]+=1

opening=""
dict2={}
for i in range(0,5):
    max=0
    for key in dict:
        if(dict[key]>max and (key not in dict2)):
            max=dict[key]
            opening=key
    dict2[opening]=max

# %%
#white
w=dict2.keys()
l=dict2.values()
plt.figure(figsize=(20,10))
plt.bar(w,l)
# Out:
# <BarContainer object of 5 artists>

# %%
dict={}
for ind, row in df.iterrows():
    if(row['opening_name'] not in dict):
        dict[row['opening_name']]=0
    if(row['winner']=='black'):
        dict[row['opening_name']]+=1

opening=""
dict2={}
for i in range(0,5):
    max=0
    for key in dict:
        if(dict[key]>max and (key not in dict2)):
            max=dict[key]
            opening=key
    dict2[opening]=max

# %%
#black
w=dict2.keys()
l=dict2.values()
plt.figure(figsize=(20,10))
plt.bar(w,l)
# Out:
# <BarContainer object of 5 artists>

# %% [markdown]
# This gives us the openings with the most amount of wins for both black and white. Because some opening may be played more often than others, it may be benificial and more accurate to create a seperate function to provide a win/loss ratio for each opening.
